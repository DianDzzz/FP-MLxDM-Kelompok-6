# %% [markdown]
# # Preprocessing from Raw Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from src.preprocessing import apply_anomaly_detection, add_temporal_and_lag_features
# Out:
# /tmp/ipykernel_65060/541231477.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../data/raw-dataset.csv")

# %%
df.head()
# Out:
#        id  rfid_tag                  checkin_time  \
# 0  231966  6A3599CB                           NaN
# 1  231965  5AEC24CB  2025-12-10 21:54:41.57978+00
# 2  231964  DAFD7CC0                           NaN
# 3  231963  4AECC6CB                           NaN
# 4  231962  6A48BDCB                           NaN
#
#                    checkout_time note        date
# 0                            NaN  NaN  2025-12-11
# 1  2025-12-11 04:12:48.000143+00  NaN  2025-12-11
# 2                            NaN  NaN  2025-12-11
# 3                            NaN  NaN  2025-12-11
# 4                            NaN  NaN  2025-12-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183755 entries, 0 to 183754
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             183755 non-null  int64
#  1   rfid_tag       183755 non-null  object
#  2   checkin_time   75502 non-null   object
#  3   checkout_time  44666 non-null   object
#  4   note           118278 non-null  object
#  5   date           183755 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 8.4+ MB

# %% [markdown]
# ## Anomaly Detection Cleaning

# %%
df_clean = apply_anomaly_detection(df, contamination=0.05) # asumsi 5% data adalah anomali
# Out:
# --- Anomaly Detection (Isolation Forest) ---
# Total data valid (checkin ada): 75502
# Terdeteksi 3771 anomali teknis. Contoh:
#                         checkin_time                    checkout_time  \
# 8   2025-12-11 02:53:19.911990+00:00 2025-12-11 03:01:20.076312+00:00
# 70  2025-12-11 03:17:26.788000+00:00 2025-12-11 03:17:32.934234+00:00
# 271 2025-12-11 04:03:27.229651+00:00 2025-12-11 04:03:33.082209+00:00
# 352 2025-12-10 23:35:18.808963+00:00                              NaT
# 436 2025-12-11 05:07:50.448217+00:00 2025-12-11 05:07:56.988642+00:00
#
#      duration_hours
# 8          0.133379
# 70         0.001707
# 271        0.001626
# 352        0.000000
# 436        0.001817
# Data setelah pembersihan anomali: 179984

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Without Anomaly Detection Cleaning

# %%
df_without_anomaly = add_temporal_and_lag_features(df)

# %%
df_without_anomaly.to_csv("../data/processed_data_without_anomaly.csv", index=False)

# %% [markdown]
# ### With Anomaly Detection Cleaning

# %%
df_with_anomaly = add_temporal_and_lag_features(df_clean)

# %%
df_with_anomaly.to_csv("../data/processed_data_with_anomaly.csv", index=False)
