# %%
import pandas as pd

# %%
df = pd.read_csv("attendance_with_features.csv")

# %%
# sorting data berdasarkan kolom "id" yang paling besar ke yang paling kecil
df_sorted = df.sort_values(by="id", ascending=False)
df_sorted.to_csv("sorted_attendance_data.csv", index=False)
